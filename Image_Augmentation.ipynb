# %%
pip install -U albumentations

# %%
import albumentations as A
import matplotlib.pyplot as plt
import cv2

# %%
from google.colab.patches import cv2_imshow

# %%
# Declare an augmentation pipeline
transform = A.Compose([
    A.RandomCrop(width=256, height=256),
    A.HorizontalFlip(p=0.5),
    A.RandomBrightnessContrast(p=0.2),
    A.VerticalFlip(p = 0.5)
])

# %%
# Read an image with OpenCV and convert it to the RGB colorspace
image = cv2.imread("/content/Rich Aroma Familie-16.webp")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=490x602 at 0x7F0661939D90>

# %%
# Augment an image
transformed = transform(image=image)
transformed_image = transformed["image"]

# %%
cv2_imshow(transformed_image)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F066192FED0>
